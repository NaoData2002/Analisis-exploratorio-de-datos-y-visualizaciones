# %% [markdown]
# Ejercicio 1

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
url = 'https://raw.githubusercontent.com/LlaczaData/Analisis-exploratorio-de-datos-y-visualizaciones/main/TV%20Shows%20-%20Netflix.csv'
df_series = pd.read_csv(url)
df_series
# Out:
#                                Titles  Year Rating  IMDB_Rating  Netflix
# 0                        Breaking Bad  2008    18+          9.5        1
# 1                     Game of Thrones  2011    18+          9.3        0
# 2                      Rick and Morty  2013    18+          9.2        0
# 3                                Dark  2017    16+          8.8        1
# 4                     Stranger Things  2016    16+          8.8        1
# 5          Avatar: The Last Airbender  2005     7+          9.2        1
# 6                            Sherlock  2010    16+          9.1        1
# 7                           Chernobyl  2019    18+          9.4        0
# 8                             Friends  1994    16+          8.9        0
# 9                          The Office  2005    16+          8.9        1
# 10                   Better Call Saul  2015    18+          8.7        1
# 11                           The Wire  2002    18+          9.3        0
# ...

# %% [markdown]
# Ejercicio 2

# %%
df_series.columns
# Out:
# Index(['Titles', 'Year', 'Rating', 'IMDB_Rating', 'Netflix'], dtype='object')

# %%
df_series.info()

# %%
df_series.head(10)
# Out:
#                        Titles  Year Rating  IMDB_Rating  Netflix
# 0                Breaking Bad  2008    18+          9.5        1
# 1             Game of Thrones  2011    18+          9.3        0
# 2              Rick and Morty  2013    18+          9.2        0
# 3                        Dark  2017    16+          8.8        1
# 4             Stranger Things  2016    16+          8.8        1
# 5  Avatar: The Last Airbender  2005     7+          9.2        1
# 6                    Sherlock  2010    16+          9.1        1
# 7                   Chernobyl  2019    18+          9.4        0
# 8                     Friends  1994    16+          8.9        0
# 9                  The Office  2005    16+          8.9        1

# %%
df_series.tail(10)
# Out:
#                                Titles  Year Rating  IMDB_Rating  Netflix
# 40                             Fringe  2008    16+          8.4        0
# 41                      Modern Family  2009    16+          8.4        0
# 42                The Big Bang Theory  2007    16+          8.1        0
# 43                            Firefly  2002    16+          9.0        0
# 44                            Mad Men  2007    16+          8.6        0
# 45   Fullmetal Alchemist: Brotherhood  2009    18+          9.1        0
# 46                              Ozark  2017    18+          8.4        1
# 47                        The Witcher  2019    18+          8.2        1
# 48                            Lucifer  2016    16+          8.2        1
# 49  It's Always Sunny in Philadelphia  2005    18+          8.8        0

# %%
df_series.columns
# Out:
# Index(['Titles', 'Year', 'Rating', 'IMDB_Rating', 'Netflix'], dtype='object')

# %%
df_series.describe()
# Out:
#               Year  IMDB_Rating    Netflix
# count    50.000000    50.000000  50.000000
# mean   2009.900000     8.722000   0.380000
# std       6.746881     0.358734   0.490314
# min    1989.000000     8.000000   0.000000
# 25%    2005.250000     8.500000   0.000000
# 50%    2011.000000     8.700000   0.000000
# 75%    2015.000000     8.900000   1.000000
# max    2019.000000     9.500000   1.000000

# %% [markdown]
# Ejercicio 3

# %%
sns.kdeplot(df_series['IMDB_Rating'], bw=0.5)
# Out:
# <ipython-input-18-f3ddca9f70c4>:1: UserWarning:
#
# The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`.
# Setting `bw_method=0.5`, but please see the docs for the new parameters
# and update your code. This will become an error in seaborn v0.13.0.
#
#   sns.kdeplot(df_series['IMDB_Rating'], bw=0.5)
# <Axes: xlabel='IMDB_Rating', ylabel='Density'>

# %%
sns.histplot(data=df_movies, x="IMDB_Rating", y="Year")
# Out:
# <Axes: xlabel='IMDB_Rating', ylabel='Year'>

# %%
sns.scatterplot(data=df_movies, x="IMDB_Rating", y="Year")
# Out:
# <Axes: xlabel='IMDB_Rating', ylabel='Year'>

# %%
sns.barplot(x = "Rating", y = "IMDB_Rating", data = df_movies)
# Out:
# <Axes: xlabel='Rating', ylabel='IMDB_Rating'>

# %% [markdown]
# Ejercicio 4

# %%
df_seriesact = df_series['Year'] > 2000
movies_2000 = df_series[df_seriesact]

# %%
movies_2000
# Out:
#                                Titles  Year Rating  IMDB_Rating  Netflix
# 0                        Breaking Bad  2008    18+          9.5        1
# 1                     Game of Thrones  2011    18+          9.3        0
# 2                      Rick and Morty  2013    18+          9.2        0
# 3                                Dark  2017    16+          8.8        1
# 4                     Stranger Things  2016    16+          8.8        1
# 5          Avatar: The Last Airbender  2005     7+          9.2        1
# 6                            Sherlock  2010    16+          9.1        1
# 7                           Chernobyl  2019    18+          9.4        0
# 9                          The Office  2005    16+          8.9        1
# 10                   Better Call Saul  2015    18+          8.7        1
# 11                           The Wire  2002    18+          9.3        0
# 12                       Supernatural  2005    16+          8.4        0
# ...

# %%
df_seriesadult = df_series['Rating'] == "18+"
series_18 = df_series[df_seriesadult]

# %%
series_18
# Out:
#                                Titles  Year Rating  IMDB_Rating  Netflix
# 0                        Breaking Bad  2008    18+          9.5        1
# 1                     Game of Thrones  2011    18+          9.3        0
# 2                      Rick and Morty  2013    18+          9.2        0
# 7                           Chernobyl  2019    18+          9.4        0
# 10                   Better Call Saul  2015    18+          8.7        1
# 11                           The Wire  2002    18+          9.3        0
# 13                              Fargo  2014    18+          8.9        0
# 14                       Black Mirror  2011    18+          8.8        1
# 15                   Band of Brothers  2001    18+          9.4        0
# 18                        Money Heist  2017    18+          8.4        1
# 19                     Peaky Blinders  2013    18+          8.8        1
# 20                          Mr. Robot  2015    18+          8.5        0
# ...

# %% [markdown]
# Ejercicio 5

# %%
df_seriesaño = df_series.sort_values("Year")
df_seriesaño
# Out:
#                                Titles  Year Rating  IMDB_Rating  Netflix  \
# 23                       The Simpsons  1989     7+          8.7        0
# 8                             Friends  1994    16+          8.9        0
# 35                         South Park  1997    18+          8.7        0
# 22                       The Sopranos  1999    18+          9.2        0
# 15                   Band of Brothers  2001    18+          9.4        0
# 43                            Firefly  2002    16+          9.0        0
# 11                           The Wire  2002    18+          9.3        0
# 25                               Lost  2004    16+          8.3        0
# 17                              House  2004    16+          8.7        0
# 9                          The Office  2005    16+          8.9        1
# 5          Avatar: The Last Airbender  2005     7+          9.2        1
# 12                       Supernatural  2005    16+          8.4        0
# ...

# %%
df_seriesimdbrating = df_series.sort_values('IMDB_Rating',ascending=False)
df_seriesimdbrating
# Out:
#                                Titles  Year Rating  IMDB_Rating  Netflix  \
# 0                        Breaking Bad  2008    18+          9.5        1
# 7                           Chernobyl  2019    18+          9.4        0
# 15                   Band of Brothers  2001    18+          9.4        0
# 1                     Game of Thrones  2011    18+          9.3        0
# 11                           The Wire  2002    18+          9.3        0
# 22                       The Sopranos  1999    18+          9.2        0
# 5          Avatar: The Last Airbender  2005     7+          9.2        1
# 2                      Rick and Morty  2013    18+          9.2        0
# 6                            Sherlock  2010    16+          9.1        1
# 45   Fullmetal Alchemist: Brotherhood  2009    18+          9.1        0
# 29                     True Detective  2014    18+          9.0        0
# 43                            Firefly  2002    16+          9.0        0
# ...

# %% [markdown]
# Ejercicio 6

# %%
df_series['Calificación por año'] = df_series['IMDB_Rating'] + df_series['Year']

# %%
df_series
# Out:
#                                Titles  Year Rating  IMDB_Rating  Netflix  \
# 0                        Breaking Bad  2008    18+          9.5        1
# 1                     Game of Thrones  2011    18+          9.3        0
# 2                      Rick and Morty  2013    18+          9.2        0
# 3                                Dark  2017    16+          8.8        1
# 4                     Stranger Things  2016    16+          8.8        1
# 5          Avatar: The Last Airbender  2005     7+          9.2        1
# 6                            Sherlock  2010    16+          9.1        1
# 7                           Chernobyl  2019    18+          9.4        0
# 8                             Friends  1994    16+          8.9        0
# 9                          The Office  2005    16+          8.9        1
# 10                   Better Call Saul  2015    18+          8.7        1
# 11                           The Wire  2002    18+          9.3        0
# ...

# %%
df_series['Calificación por serie de Netflix'] = df_series['IMDB_Rating'] + df_series['Netflix']

# %%
df_series
# Out:
#                                Titles  Year Rating  IMDB_Rating  Netflix  \
# 0                        Breaking Bad  2008    18+          9.5        1
# 1                     Game of Thrones  2011    18+          9.3        0
# 2                      Rick and Morty  2013    18+          9.2        0
# 3                                Dark  2017    16+          8.8        1
# 4                     Stranger Things  2016    16+          8.8        1
# 5          Avatar: The Last Airbender  2005     7+          9.2        1
# 6                            Sherlock  2010    16+          9.1        1
# 7                           Chernobyl  2019    18+          9.4        0
# 8                             Friends  1994    16+          8.9        0
# 9                          The Office  2005    16+          8.9        1
# 10                   Better Call Saul  2015    18+          8.7        1
# 11                           The Wire  2002    18+          9.3        0
# ...

# %% [markdown]
# Ejercicio 7

# %%
calificacion_año = df_series.groupby('IMDB_Rating')

# %%
calificacion_año

# %%
resultado = calificacion_año['IMDB_Rating'].sum()

# %%
resultado

# %%
resultado1 = calificacion_año['IMDB_Rating'].agg(['sum', 'mean','count'])

# %%
resultado1
# Out:
#               sum  mean  count
# IMDB_Rating
# 8.0           8.0   8.0      1
# 8.1           8.1   8.1      1
# 8.2          24.6   8.2      3
# 8.3           8.3   8.3      1
# 8.4          50.4   8.4      6
# 8.5          42.5   8.5      5
# 8.6          43.0   8.6      5
# 8.7          52.2   8.7      6
# 8.8          61.6   8.8      7
# 8.9          26.7   8.9      3
# 9.0          18.0   9.0      2
# 9.1          18.2   9.1      2
# 9.2          27.6   9.2      3
# 9.3          18.6   9.3      2
# 9.4          18.8   9.4      2
# 9.5           9.5   9.5      1
